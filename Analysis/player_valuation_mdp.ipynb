# %%
import pandas as pd
from SQLCode import DatabaseConnection
from SQLCode import DatabaseCredentials as DBC
import numpy as np

# %%
# Opening connection
creds = DBC.DataBaseCredentials()
conn = DatabaseConnection.sql_connection(creds.server, creds.database, creds.user, creds.password)
connection = conn.open()
cursor = connection.cursor()

# %%
# Getting the live_feed data
liveFeed = pd.read_sql_query("select * from live_feed where gameID >= 20102011", connection)

# %%
# Getting the seasons data
seasons = pd.read_sql_query("select * from schedules", connection)

# %%
boxscores = pd.read_sql_query("select gameID, teamID, playerID from box_scores where gameID >= 2010010001", connection)

# %%
# Filtering to regular seasons games and 20102011 onwards (when live data started)
seasonsFiltered = seasons[seasons['seasonID'] >= 20102011]
seasonsFiltered = seasonsFiltered[seasonsFiltered['gameType'] == 'R']

# %%
# Getting and filtering the raw data
rawData = pd.merge(liveFeed,seasons, how='right',on='gameID')
rawData = rawData[rawData['seasonID'] >= 20102011]
# rawData = rawData[rawData['gameType'] == 'R']

# %%
# Merging box score data
rawData = pd.merge(rawData, 
                   boxscores, 
                   how='left', 
                   left_on=['gameID', 'playerID'], 
                   right_on=['gameID', 'playerID'],
                   suffixes=('', '_box'))

# %%
# Filtering to test game
rawData = rawData[rawData['gameID'] == 2020030312]

# %%
# Getting only the desired events
rawDataFiltered = rawData[rawData['eventTypeID'].isin(['FACEOFF',
                             'SHOT',
                             'MISSED_SHOT',
                             'BLOCKED_SHOT',
                             'TAKEAWAY',
                             'GIVEAWAY',
                             'HIT',
                             'GOAL',
                             'PERIOD_START',
                             'PERIOD_END',
                             'EARLY_INT_START',
                             'PENALTY',
                             'STOP',
                             'SHOOTOUT_COMPLETE',
                             'GAME_END',
                             'EARLY_INT_END',
                             'EARLY_INT_END'])]
# rawDataFiltered = rawDataFiltered[rawDataFiltered['playerType'].isin(['NULL', 
#                                    'Winner', 
#                                    'Loser', 
#                                    'Hitter', 
#                                    'PlayerID','Shooter','Blocker','Unknown','Scorer','PenaltyOn','DrewBy'])]
# Sorting
rawDataFiltered = rawDataFiltered.sort_values(by=['gameID', 'periodNum','periodTime'])

# %%
def team_type(teamID, homeTeamID, awayTeamID):
    if teamID == homeTeamID:
        return 'HOME'
    elif teamID == awayTeamID:
        return 'AWAY'
    else:
        return np.nan

def zone(xCoord, teamType, periodNum):
    if teamType == np.nan:
        return 'NEUTRAL'
    if (xCoord >= -25) & (xCoord < 25):
        return 'NEUTRAL'
    else:
        if int(periodNum)%2 == 1:
            if (xCoord > 25) & (teamType == 'AWAY'):
                return 'OFFENSIVE'
            elif (xCoord < -25) & (teamType == 'AWAY'):
                return 'DEFENSIVE'
            elif (xCoord > 25) & (teamType == 'HOME'):
                return 'DEFENSIVE'
            elif (xCoord < -25) & (teamType == 'HOME'):
                return 'OFFENSIVE'
        else:
            if (xCoord > 25) & (teamType == 'AWAY'):
                return 'DEFENSIVE'
            elif (xCoord < -25) & (teamType == 'AWAY'):
                return 'OFFENSIVE'
            elif (xCoord > 25) & (teamType == 'HOME'):
                return 'OFFENSIVE'
            elif (xCoord < -25) & (teamType == 'HOME'):
                return 'DEFENSIVE'

# %%
rawDataFiltered['zone'] = rawDataFiltered.apply(lambda row: zone(row['xCoordinate'],
                                       team_type(row['teamID'], 
                                                 row['homeTeamID'], 
                                                 row['awayTeamID']), row['periodNum']) ,axis=1)

# %%
rawDataFiltered
# Out:
#          eventID  eventSubID      gameID         event eventCode  \
# 7687157      8.0         0.0  2020030312  Period Start      VGK8
# 7687223     51.0         0.0  2020030312       Faceoff     VGK51
# 7687224     51.0         1.0  2020030312       Faceoff     VGK51
# 7687158      9.0         0.0  2020030312      Stoppage      VGK9
# 7687225     52.0         0.0  2020030312       Faceoff     VGK52
# ...          ...         ...         ...           ...       ...
# 7687786    776.0         1.0  2020030312   Missed Shot    VGK776
# 7687787    777.0         0.0  2020030312  Blocked Shot    VGK777
# 7687788    777.0         1.0  2020030312  Blocked Shot    VGK777
# 7687817    821.0         0.0  2020030312    Period End    VGK821
# 7687819    825.0         0.0  2020030312      Game End    VGK825
#
#           eventTypeID                                   eventDescription  \
# 7687157  PERIOD_START                                       Period Start
# 7687223       FACEOFF  Phillip Danault faceoff won against William Ka...
# 7687224       FACEOFF  Phillip Danault faceoff won against William Ka...
# 7687158          STOP                                              Icing
# 7687225       FACEOFF  Phillip Danault faceoff won against William Ka...
# ...               ...                                                ...
# 7687786   MISSED_SHOT              Alec Martinez Wide of Net Carey Price
# 7687787  BLOCKED_SHOT   Alex Pietrangelo shot blocked shot by Shea Weber
# 7687788  BLOCKED_SHOT   Alex Pietrangelo shot blocked shot by Shea Weber
# 7687817    PERIOD_END                                  End of 3rd Period
# 7687819      GAME_END                                           Game End
#
#         secondaryType periodNum      periodTime  ...  strength  \
# 7687157          None         1 0 days 00:00:00  ...      None
# 7687223          None         1 0 days 00:00:00  ...      None
# 7687224          None         1 0 days 00:00:00  ...      None
# 7687158          None         1 0 days 00:11:00  ...      None
# 7687225          None         1 0 days 00:11:00  ...      None
# ...               ...       ...             ...  ...       ...
# 7687786          None         3 0 days 19:49:00  ...      None
# 7687787          None         3 0 days 19:56:00  ...      None
# 7687788          None         3 0 days 19:56:00  ...      None
# 7687817          None         3 0 days 20:00:00  ...      None
# 7687819          None         3 0 days 20:00:00  ...      None
#
#         gameWinningGoal  emptyNetGoal  seasonID  gameType    gameDate  \
# 7687157             NaN           NaN  20202021         P  2021-06-16
# 7687223             NaN           NaN  20202021         P  2021-06-16
# 7687224             NaN           NaN  20202021         P  2021-06-16
# 7687158             NaN           NaN  20202021         P  2021-06-16
# 7687225             NaN           NaN  20202021         P  2021-06-16
# ...                 ...           ...       ...       ...         ...
# 7687786             NaN           NaN  20202021         P  2021-06-16
# 7687787             NaN           NaN  20202021         P  2021-06-16
# 7687788             NaN           NaN  20202021         P  2021-06-16
# 7687817             NaN           NaN  20202021         P  2021-06-16
# 7687819             NaN           NaN  20202021         P  2021-06-16
#
#          homeTeamID awayTeamID  teamID_box       zone
# 7687157          54          8         NaN       None
# 7687223          54          8         8.0    NEUTRAL
# 7687224          54          8        54.0    NEUTRAL
# 7687158          54          8         NaN       None
# 7687225          54          8         8.0  OFFENSIVE
# ...             ...        ...         ...        ...
# 7687786          54          8         8.0  OFFENSIVE
# 7687787          54          8         8.0  DEFENSIVE
# 7687788          54          8        54.0  DEFENSIVE
# 7687817          54          8         NaN       None
# 7687819          54          8         NaN       None
#
# [658 rows x 27 columns]

# %%
rawDataFiltered[np.where(pd.isna(rawDataFiltered['teamID']), 
         True, 
         np.where(rawDataFiltered['homeTeamID'] == rawDataFiltered['teamID_box'], True,False))]
# Out:
#          eventID  eventSubID      gameID         event eventCode  \
# 7687157      8.0         0.0  2020030312  Period Start      VGK8
# 7687224     51.0         1.0  2020030312       Faceoff     VGK51
# 7687158      9.0         0.0  2020030312      Stoppage      VGK9
# 7687226     52.0         1.0  2020030312       Faceoff     VGK52
# 7687227     53.0         0.0  2020030312  Blocked Shot     VGK53
# ...          ...         ...         ...           ...       ...
# 7687816    820.0         0.0  2020030312      Stoppage    VGK820
# 7687785    776.0         0.0  2020030312   Missed Shot    VGK776
# 7687788    777.0         1.0  2020030312  Blocked Shot    VGK777
# 7687817    821.0         0.0  2020030312    Period End    VGK821
# 7687819    825.0         0.0  2020030312      Game End    VGK825
#
#           eventTypeID                                   eventDescription  \
# 7687157  PERIOD_START                                       Period Start
# 7687224       FACEOFF  Phillip Danault faceoff won against William Ka...
# 7687158          STOP                                              Icing
# 7687226       FACEOFF  Phillip Danault faceoff won against William Ka...
# 7687227  BLOCKED_SHOT  Brendan Gallagher shot blocked shot by Alec Ma...
# ...               ...                                                ...
# 7687816          STOP                                      Puck in Crowd
# 7687785   MISSED_SHOT              Alec Martinez Wide of Net Carey Price
# 7687788  BLOCKED_SHOT   Alex Pietrangelo shot blocked shot by Shea Weber
# 7687817    PERIOD_END                                  End of 3rd Period
# 7687819      GAME_END                                           Game End
#
#         secondaryType periodNum      periodTime  ...  strength  \
# 7687157          None         1 0 days 00:00:00  ...      None
# 7687224          None         1 0 days 00:00:00  ...      None
# 7687158          None         1 0 days 00:11:00  ...      None
# 7687226          None         1 0 days 00:11:00  ...      None
# 7687227          None         1 0 days 00:16:00  ...      None
# ...               ...       ...             ...  ...       ...
# 7687816          None         3 0 days 19:39:00  ...      None
# 7687785          None         3 0 days 19:49:00  ...      None
# 7687788          None         3 0 days 19:56:00  ...      None
# 7687817          None         3 0 days 20:00:00  ...      None
# 7687819          None         3 0 days 20:00:00  ...      None
#
#         gameWinningGoal  emptyNetGoal  seasonID  gameType    gameDate  \
# 7687157             NaN           NaN  20202021         P  2021-06-16
# 7687224             NaN           NaN  20202021         P  2021-06-16
# 7687158             NaN           NaN  20202021         P  2021-06-16
# 7687226             NaN           NaN  20202021         P  2021-06-16
# 7687227             NaN           NaN  20202021         P  2021-06-16
# ...                 ...           ...       ...       ...         ...
# 7687816             NaN           NaN  20202021         P  2021-06-16
# 7687785             NaN           NaN  20202021         P  2021-06-16
# 7687788             NaN           NaN  20202021         P  2021-06-16
# 7687817             NaN           NaN  20202021         P  2021-06-16
# 7687819             NaN           NaN  20202021         P  2021-06-16
#
#          homeTeamID awayTeamID  teamID_box       zone
# 7687157          54          8         NaN       None
# 7687224          54          8        54.0    NEUTRAL
# 7687158          54          8         NaN       None
# 7687226          54          8        54.0  OFFENSIVE
# 7687227          54          8        54.0  DEFENSIVE
# ...             ...        ...         ...        ...
# 7687816          54          8         NaN       None
# 7687785          54          8        54.0  OFFENSIVE
# 7687788          54          8        54.0  DEFENSIVE
# 7687817          54          8         NaN       None
# 7687819          54          8         NaN       None
#
# [364 rows x 27 columns]

# %%
rawDataFilteredHome = rawDataFiltered[np.where(pd.isna(rawDataFiltered['teamID']), 
         True, 
         np.where(rawDataFiltered['teamID'] == rawDataFiltered['teamID_box'], True,False))]

rawDataFilteredAway = rawDataFiltered[np.where(pd.isna(rawDataFiltered['teamID']), 
         True, 
         np.where(rawDataFiltered['teamID'] == rawDataFiltered['teamID_box'], True,False))]

# %%
sequences = []
actionEvents = ['FACEOFF',
                'SHOT',
                'MISSED_SHOT',
                'BLOCKED_SHOT',
                'TAKEAWAY',
                'GIVEAWAY',
                'HIT',
                'GOAL']
startEndEvents = ['PERIOD_START',
                  'PERIOD_END',
                  'EARLY_INT_START',
                  'PENALTY',
                  'STOP',
                  'SHOOTOUT_COMPLETE',
                  'GAME_END',
                  'EARLY_INT_END',
                  'EARLY_INT_END']
sequenceNum = 0
eventNum = 0
for index, row in rawDataFilteredHome.iterrows():
    sequences.append([row['gameID'], 
                      row['periodNum'], 
                      sequenceNum, 
                      eventNum, 
                      row['eventTypeID'], 
                      team_type(row['teamID'], row['homeTeamID'], row['awayTeamID']), 
                      row['zone']])
    if row['eventTypeID'] in actionEvents:
        eventNum += 1
    else:
        sequenceNum += 1
        eventNum = 0
sequenceDataHome = pd.DataFrame(sequences, columns=['gameID', 'periodNum', 'sequenceNum',' eventNum','event', 'team', 'zone'])

# %%
sequences = []
actionEvents = ['FACEOFF',
                'SHOT',
                'MISSED_SHOT',
                'BLOCKED_SHOT',
                'TAKEAWAY',
                'GIVEAWAY',
                'HIT',
                'GOAL']
startEndEvents = ['PERIOD_START',
                  'PERIOD_END',
                  'EARLY_INT_START',
                  'PENALTY',
                  'STOP',
                  'SHOOTOUT_COMPLETE',
                  'GAME_END',
                  'EARLY_INT_END',
                  'EARLY_INT_END']
sequenceNum = 0
eventNum = 0
for index, row in rawDataFilteredAway.iterrows():
    sequences.append([row['gameID'], 
                      row['periodNum'], 
                      sequenceNum, 
                      eventNum, 
                      row['eventTypeID'], 
                      team_type(row['teamID'], row['homeTeamID'], row['awayTeamID']), 
                      row['zone']])
    if row['eventTypeID'] in actionEvents:
        eventNum += 1
    else:
        sequenceNum += 1
        eventNum = 0
sequenceDataAway = pd.DataFrame(sequences, columns=['gameID', 'periodNum', 'sequenceNum',' eventNum','event', 'team', 'zone'])

# %%
sequenceDataAway
# Out:
#          gameID periodNum  sequenceNum   eventNum         event event  \
# 0    2020030312         1            0          0  PERIOD_START   NaN
# 1    2020030312         1            1          0       FACEOFF  AWAY
# 2    2020030312         1            1          1          STOP   NaN
# 3    2020030312         1            2          0       FACEOFF  AWAY
# 4    2020030312         1            2          1  BLOCKED_SHOT   NaN
# ..          ...       ...          ...        ...           ...   ...
# 374  2020030312         3           57          3          STOP   NaN
# 375  2020030312         3           58          0   MISSED_SHOT   NaN
# 376  2020030312         3           58          1  BLOCKED_SHOT  AWAY
# 377  2020030312         3           58          2    PERIOD_END   NaN
# 378  2020030312         3           59          0      GAME_END   NaN
#
#           zone
# 0         None
# 1      NEUTRAL
# 2         None
# 3    OFFENSIVE
# 4         None
# ..         ...
# 374       None
# 375       None
# 376  DEFENSIVE
# 377       None
# 378       None
#
# [379 rows x 7 columns]
